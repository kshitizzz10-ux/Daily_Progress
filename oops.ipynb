# %%
print("READY FOR DAY 1")
# Out:
# READY FOR DAY 1

# %%
#inefficient class method
class Employee:
    pass
emp_1 = Employee()
emp_2 = Employee()
print(emp_1)
print(emp_2)
emp_1.first = 'kSHITIZ'
emp_1.last = 'Goyal'
emp_1.email = 'kshitiz.goyal@company.com'
emp_1.pay = 50000
emp_2.first = 'Pakhi'
emp_2.last = 'Shukla'
emp_2.email = 'pakhi.shukla@company.com'
emp_2.pay = 60000
print(emp_1.email)
print(emp_2.email)
# Out:
# ...
# kshitiz.goyal@company.com
# pakhi.shukla@company.com

# %%
#efficient class method 
class Employeee:
    raise_amount = 1.04
    num_of_employeees = 0
    def __init__(self,first,last,pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+'.'+last+'@company.com'
        Employeee.num_of_employeees += 1
    def fullname(self):
        return'{} {}'.format(self.first,self.last)
    def apply_raise(self):
        self.pay= int(self.pay*self.raise_amount)

emp_11 = Employeee('Dishu','Sharma',90000)
emp_12 = Employeee('atharva','nagane',78000)
# print(emp_11.pay,emp_11.email)
# print(emp_12.pay,emp_12.email)
# print(emp_11.fullname())
# print(emp_12.fullname())
# print(emp_11.pay)
# emp_11.apply_raise()
# print(emp_11.pay)
# print(Employeee.__dict__)
# Employeee.raise_amount=1.06
# emp_11.raise_amount=1.09
# print(Employeee.raise_amount)
# print(emp_11.raise_amount)
# print(emp_12.raise_amount)
# print(Employeee.num_of_employeees)
# Out:
# 0
