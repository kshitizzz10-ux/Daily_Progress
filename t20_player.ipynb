# %%
class t20Innings:
    def __init__(self,batting_team,bowling_team):
        self.batting_team = batting_team
        self.bowling_team = bowling_team
        self._runscored = 0
        self._wickets = 0
        self._legaldel = 0
        self._extras = 0
match_A = t20Innings(batting_team = "India", bowling_team = "Australia")
match_B = t20Innings(batting_team="CSK", bowling_team="RCB")
print(f"Batting team of match A is {match_A.batting_team}")
